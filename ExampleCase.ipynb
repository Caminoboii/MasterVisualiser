# %% [markdown]
# # Growth Curve
# Writing a grotwh data file and plotting the rsult

# %%
from GrowthCurve import GrowthCurveVisualiser

# %%
GrowthCurveVisualiser.create_data_file(name = "Data/GrowthCurve/Example.csv", time = [0, 1, 2, 3, 4, 5], absorbance = [0.1, 0.2, 0.4, 0.8, 1.6, 3.2], sample_volume = [200,200,200,200,150]
# Out:
# Data saved to Data/Growth/Example.csv

# %%
Example = GrowthCurveVisualiser("Data/Growth/Example.csv")
# Out:
# Figure saved to: Data/Growth/Plots/082426_HERV-K_CA.png
# Figure saved to: Data/Growth/Plots/082426_HERV-K_CANC.png

# %% [markdown]
# # AKTA
# Loading and plotting data from an AKTA

# %%
from Akta import AktaVisualiser

# %%
example_akta = AktaVisualiser("Data/AKTA/EXAMPLE.csv")
example_akta.read_data()

example_akta.read_data()

example_akta.eluation_plot(title = "Example Case")
example_akta.eluation_plot(x_min = 20,y_min= 0, y_max = 400, title = "Example Case ZOOM")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 example_akta = AktaVisualiser("Data/AKTA/EXAMPLE.csv")
#       2 example_akta.read_data_affinity()
#       3
# ----> 4 example_akta.read_data_affinity_test()
#       5
#       6 example_akta.eluation_plot(title = "Example Case")
#       7 example_akta.eluation_plot(x_min = 20,y_min= 0, y_max = 400, title = "Example Case ZOOM")
#
# AttributeError: 'AktaVisualiser' object has no attribute 'read_data_affinity_test'

# %% [markdown]
# # Nanodrop
# Calculating protein concentration from absorbance

# %%
from Nanodrop import Nanodrop

nanodroptest = Nanodrop(0.07, molar_extinction_coefficient= 37930, mass_extinction_coefficient= 1.330)
nanodroptest.calculate_molar_concentration()
nanodroptest.calculate_mg_per_mL_concentration()
# Out:
# Molar Concentration: 1.8455e-06 M
# Molar Concentration: 1.8455 µM
# Concentration: 5.2632e-02 mg/mL
# 0.052631578947368425
